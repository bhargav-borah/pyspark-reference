# %%
# !pip install pyspark
# Out:
# ...
#      -------------------------------------- 317.0/317.0 MB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ------------------------------------ 200.5/200.5 kB 607.8 kB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488515 sha256=a693ed9f3065c480f3f038a7172a78e55658c8afbf86c74ebf88571d4a412fb8
#   Stored in directory: c:\users\anupa\appdata\local\pip\cache\wheels\92\09\11\aa01d01a7f005fda8a66ad71d2be7f8aa341bddafb27eee3c7
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Practice').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ANUPAM:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import pandas as pd
pd.read_csv('data/melb_data.csv')
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# ...

# %%
df = spark.read.csv('data/melb_data.csv')

# %%
df
# Out:
# DataFrame[_c0: string, _c1: string, _c2: string, _c3: string, _c4: string, _c5: string, _c6: string, _c7: string, _c8: string, _c9: string, _c10: string, _c11: string, _c12: string, _c13: string, _c14: string, _c15: string, _c16: string, _c17: string, _c18: string, _c19: string, _c20: string]

# %%
df.show()
# Out:
# +----------+-------------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+----+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# |       _c0|                _c1|  _c2| _c3|      _c4|   _c5|    _c6|       _c7|     _c8|     _c9|    _c10|    _c11|_c12|    _c13|        _c14|     _c15|       _c16|     _c17|      _c18|                _c19|         _c20|
# +----------+-------------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+----+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# |    Suburb|            Address|Rooms|Type|    Price|Method|SellerG|      Date|Distance|Postcode|Bedroom2|Bathroom| Car|Landsize|BuildingArea|YearBuilt|CouncilArea|Lattitude|Longtitude|          Regionname|Propertycount|
# ...

# %%
spark.read.option('header', 'true').csv('data/melb_data.csv').show()
# Out:
# +----------+-------------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+---+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# |    Suburb|            Address|Rooms|Type|    Price|Method|SellerG|      Date|Distance|Postcode|Bedroom2|Bathroom|Car|Landsize|BuildingArea|YearBuilt|CouncilArea|Lattitude|Longtitude|          Regionname|Propertycount|
# +----------+-------------------+-----+----+---------+------+-------+----------+--------+--------+--------+--------+---+--------+------------+---------+-----------+---------+----------+--------------------+-------------+
# |Abbotsford|       85 Turner St|    2|   h|1480000.0|     S| Biggin| 3/12/2016|     2.5|  3067.0|     2.0|     1.0|1.0|   202.0|        NULL|     NULL|      Yarra| -37.7996|  144.9984|Northern Metropol...|       4019.0|
# ...

# %%
df = spark.read.option('header', 'true').csv('data/melb_data.csv')

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.head()
# Out:
# Row(Suburb='Abbotsford', Address='85 Turner St', Rooms='2', Type='h', Price='1480000.0', Method='S', SellerG='Biggin', Date='3/12/2016', Distance='2.5', Postcode='3067.0', Bedroom2='2.0', Bathroom='1.0', Car='1.0', Landsize='202.0', BuildingArea=None, YearBuilt=None, CouncilArea='Yarra', Lattitude='-37.7996', Longtitude='144.9984', Regionname='Northern Metropolitan', Propertycount='4019.0')

# %%
df.head(3)
# Out:
# [Row(Suburb='Abbotsford', Address='85 Turner St', Rooms='2', Type='h', Price='1480000.0', Method='S', SellerG='Biggin', Date='3/12/2016', Distance='2.5', Postcode='3067.0', Bedroom2='2.0', Bathroom='1.0', Car='1.0', Landsize='202.0', BuildingArea=None, YearBuilt=None, CouncilArea='Yarra', Lattitude='-37.7996', Longtitude='144.9984', Regionname='Northern Metropolitan', Propertycount='4019.0'),
#  Row(Suburb='Abbotsford', Address='25 Bloomburg St', Rooms='2', Type='h', Price='1035000.0', Method='S', SellerG='Biggin', Date='4/02/2016', Distance='2.5', Postcode='3067.0', Bedroom2='2.0', Bathroom='1.0', Car='0.0', Landsize='156.0', BuildingArea='79.0', YearBuilt='1900.0', CouncilArea='Yarra', Lattitude='-37.8079', Longtitude='144.9934', Regionname='Northern Metropolitan', Propertycount='4019.0'),
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Suburb: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Rooms: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- Price: string (nullable = true)
#  |-- Method: string (nullable = true)
#  |-- SellerG: string (nullable = true)
#  |-- Date: string (nullable = true)
#  |-- Distance: string (nullable = true)
#  |-- Postcode: string (nullable = true)
#  |-- Bedroom2: string (nullable = true)
#  |-- Bathroom: string (nullable = true)
#  |-- Car: string (nullable = true)
#  |-- Landsize: string (nullable = true)
#  |-- BuildingArea: string (nullable = true)
#  |-- YearBuilt: string (nullable = true)
#  |-- CouncilArea: string (nullable = true)
#  |-- Lattitude: string (nullable = true)
#  |-- Longtitude: string (nullable = true)
#  |-- Regionname: string (nullable = true)
#  |-- Propertycount: string (nullable = true)
